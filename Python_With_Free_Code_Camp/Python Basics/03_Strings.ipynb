# %% [markdown]
# # Strings and Strings Immutability

# %%
my_string_01 = "Hello This is Jithendar\'s string"
print(my_string_01)
# Out:
# Hello This is Jithendar's string

# %%
my_string_02 = "Hello World"
print("Hello" in my_string_02)
# Out:
# True

# %%
my_name = "jithendar"
my_age = 32
print (my_name +"'s"+" age is :"+ str(my_age))
# Out:
# jithendar's age is :32

# %%
my_wife_name = "srilatha"
my_wife_education = "B-Tech"
total_string = my_wife_name+ ' is studied :' + my_wife_education
print(total_string)
# Out:
# srilatha is studied :B-Tech

# %%
num1 = 2026
num2 = 1993

final_year = num1 - num2

print(F'the number of years of the age id : {final_year}')
# Out:
# the number of years of the age id : 33

# %%
my_str_num = "12345678  "
print(my_str_num[::-1])
# Out:
#   87654321

# %%
#strip string
my_trip_string =my_str_num.strip()
print(my_trip_string)
# Out:
# 12345678

# %%
#replace
my_string = "hellow world"
new_string = my_string.replace( 'hellow','hi' )
print(new_string)
# Out:
# hi world

# %%
#split
print(new_string.split())
# Out:
# ['hi', 'world']
