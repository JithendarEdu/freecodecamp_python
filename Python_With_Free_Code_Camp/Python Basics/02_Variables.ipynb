# %% [markdown]
# # Declaration of Variables and Naming Conventions to Name Variables
#
# - we assign the variables in python using =
#   - we don't need special keywords like
#     ```
#     Const or
#     let
#     ```
# -

# %%
print('Jithendar Reddy')
# Out:
# Jithendar Reddy

# %%
my_integer_var = 42
print('integer:', my_integer_var)
# Out:
# integer: 42

# %%
my_set_var ={7,8,9,2}
print('Set:', my_set_var)
# Out:
# Set: {8, 9, 2, 7}

# %%
my_dictionary_var = {'name': "Jithendar", "age": 25}
print('Dictionary:', my_dictionary_var)
# Out:
# Dictionary: {'name': 'Jithendar', 'age': 25}

# %%
my_tuple_var = (1,2,3,5)
print('tuple :', my_tupule_var)
# Out:
# tuple : (1, 2, 3, 5)
